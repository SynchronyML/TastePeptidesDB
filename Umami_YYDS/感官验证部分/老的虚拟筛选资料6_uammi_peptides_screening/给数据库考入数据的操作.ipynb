# %%
import pandas as pd
from icecream import  ic
import numpy as np
import MySQLdb
from sqlalchemy import create_engine

# %%
df = pd.read_csv("Result of 8177_Candidate.csv")
df_new = df.iloc[:,:5]

# %%
df_new
# Out:
#      PepName  Taste  Probability  Vitro_verit  \
# 0         AA      1     0.792040        False
# 1         AR      0     0.101836        False
# 2         AN      1     0.991309        False
# 3         AD      1     0.992212        False
# 4         AC      1     0.805816        False
# ...      ...    ...          ...          ...
# 8172     VVP      0     0.096575        False
# 8173     VVS      0     0.064860        False
# 8174     VVT      0     0.144144        False
# 8175     VVW      0     0.005550        False
# 8176     VVY      0     0.008812        False
#
#                                        Canonical_SMILES
# 0                        C[C@H](N)C(=O)N[C@@H](C)C(=O)O
# 1               C[C@H](N)C(=O)N[C@@H](CCCNC(=N)N)C(=O)O
# 2                  C[C@H](N)C(=O)N[C@@H](CC(N)=O)C(=O)O
# 3                  C[C@H](N)C(=O)N[C@@H](CC(=O)O)C(=O)O
# 4                       C[C@H](N)C(=O)N[C@@H](CS)C(=O)O
# ...                                                 ...
# 8172  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)...
# 8173  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@@H](CO)C(=O)...
# 8174  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@H](C(=O)O)[C...
# 8175  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@@H](Cc1c[nH]...
# 8176  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@@H](Cc1ccc(O...
#
# [8177 rows x 5 columns]

# %%
df_new["Status"]=1

# %%
df_new
# Out:
#      PepName  Taste  Probability  Vitro_verit  \
# 0         AA      1     0.792040        False
# 1         AR      0     0.101836        False
# 2         AN      1     0.991309        False
# 3         AD      1     0.992212        False
# 4         AC      1     0.805816        False
# ...      ...    ...          ...          ...
# 8172     VVP      0     0.096575        False
# 8173     VVS      0     0.064860        False
# 8174     VVT      0     0.144144        False
# 8175     VVW      0     0.005550        False
# 8176     VVY      0     0.008812        False
#
#                                        Canonical_SMILES  Status
# 0                        C[C@H](N)C(=O)N[C@@H](C)C(=O)O       1
# 1               C[C@H](N)C(=O)N[C@@H](CCCNC(=N)N)C(=O)O       1
# 2                  C[C@H](N)C(=O)N[C@@H](CC(N)=O)C(=O)O       1
# 3                  C[C@H](N)C(=O)N[C@@H](CC(=O)O)C(=O)O       1
# 4                       C[C@H](N)C(=O)N[C@@H](CS)C(=O)O       1
# ...                                                 ...     ...
# 8172  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N1CCC[C@H]1C(=O)...       1
# 8173  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@@H](CO)C(=O)...       1
# 8174  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@H](C(=O)O)[C...       1
# 8175  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@@H](Cc1c[nH]...       1
# 8176  CC(C)[C@H](N)C(=O)N[C@H](C(=O)N[C@@H](Cc1ccc(O...       1
#
# [8177 rows x 6 columns]

# %%
engine = create_engine('mysql+pymysql://root:320104Czy@127.0.0.1/umamidb?charset=utf8')
df_new.to_sql(name='umami_bitter_db', con=engine, if_exists='append',
            index=False)
